# %%
# !pip install opendatasets -q

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import pandas as pd
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents")
# Out:
# Skipping, found downloaded files in "./us-accidents" (use force=True to force download)

# %%
df = pd.read_csv("/content/us-accidents/US_Accidents_March23.csv",
                 nrows = 5000000
                 )

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 1.3+ GB

# %%
print(df.isnull().sum())
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                      6593
# City                         136
# County                         0
# State                          0
# Zipcode                      844
# Country                        0
# Timezone                    4300
# Airport_Code               12552
# Weather_Timestamp          67442
# Temperature(F)             94114
# Wind_Chill(F)            1707907
# Humidity(%)               100298
# Pressure(in)               80673
# Visibility(mi)            105610
# Wind_Direction             96508
# Wind_Speed(mph)           442145
# Precipitation(in)        1840308
# Weather_Condition         102683
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             13133
# Civil_Twilight             13133
# Nautical_Twilight          13133
# Astronomical_Twilight      13133
# dtype: int64

# %%
(df == 0).sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)             2919324
# Description                    0
# Street                         0
# City                           0
# County                         0
# State                          0
# Zipcode                        0
# Country                        0
# Timezone                       0
# Airport_Code                   0
# Weather_Timestamp              0
# Temperature(F)              1610
# Wind_Chill(F)               2284
# Humidity(%)                    0
# Pressure(in)                   2
# Visibility(mi)              4445
# Wind_Direction                 0
# Wind_Speed(mph)           517322
# Precipitation(in)        2809599
# Weather_Condition              0
# Amenity                  4933368
# Bump                     4997853
# Crossing                 4378051
# Give_Way                 4972555
# Junction                 4681995
# No_Exit                  4986844
# Railway                  4954971
# Roundabout               4999829
# Station                  4870729
# Stop                     4852220
# Traffic_Calming          4995033
# Traffic_Signal           4119983
# Turning_Loop             5000000
# Sunrise_Sunset                 0
# Civil_Twilight                 0
# Nautical_Twilight              0
# Astronomical_Twilight          0
# dtype: int64

# %%
df_cleaned = df.dropna()

# %%
print("Cleaned Dataset Shape: ", df_cleaned.shape)
# Out:
# Cleaned Dataset Shape:  (1274636, 46)

# %%
print("\nRemaining Null Values:")
print(df_cleaned.isnull().sum())
# Out:
# Remaining Null Values:
# ID                       0
# Source                   0
# Severity                 0
# Start_Time               0
# End_Time                 0
# Start_Lat                0
# Start_Lng                0
# End_Lat                  0
# End_Lng                  0
# Distance(mi)             0
# Description              0
# Street                   0
# City                     0
# County                   0
# State                    0
# Zipcode                  0
# Country                  0
# Timezone                 0
# Airport_Code             0
# Weather_Timestamp        0
# Temperature(F)           0
# Wind_Chill(F)            0
# Humidity(%)              0
# Pressure(in)             0
# Visibility(mi)           0
# Wind_Direction           0
# Wind_Speed(mph)          0
# Precipitation(in)        0
# Weather_Condition        0
# Amenity                  0
# Bump                     0
# Crossing                 0
# Give_Way                 0
# Junction                 0
# No_Exit                  0
# Railway                  0
# Roundabout               0
# Station                  0
# Stop                     0
# Traffic_Calming          0
# Traffic_Signal           0
# Turning_Loop             0
# Sunrise_Sunset           0
# Civil_Twilight           0
# Nautical_Twilight        0
# Astronomical_Twilight    0
# dtype: int64

# %%
df_cleaned.to_csv('/content/cleaned_dataset.csv', index=False)

# %%
features = [
    'ID',
    'Source',
    'Severity',
    'Start_Time',
    'End_Time',
    'Start_Lat',
    'Start_Lng',
    'Distance(mi)',
    'Street',
    'City',
    'County',
    'State',
    'Country',
    'Weather_Timestamp',
    'Temperature(F)',
    'Wind_Chill(F)',
    'Humidity(%)',
    'Pressure(in)',
    'Visibility(mi)',
    'Wind_Direction',
    'Wind_Speed(mph)',
    'Precipitation(in)',
    'Weather_Condition',
    'Bump',
    'Crossing',
    'Give_Way',
    'Junction',
    'No_Exit',
    'Railway',
    'Roundabout',
    'Station',
    'Stop',
    'Traffic_Calming',
    'Traffic_Signal',
    'Turning_Loop',
    'Sunrise_Sunset'
]

# %%
df_final = df_cleaned[features]

# %%
output_file = "accident_final.csv"

# %%
df_final.to_csv(output_file, index= False)

# %%
df_final.head()
# Out:
#                 ID   Source  Severity           Start_Time  \
# 3402762  A-3412645  Source1         3  2016-02-08 00:37:08
# 3402767  A-3412650  Source1         3  2016-02-08 07:53:43
# 3402771  A-3412654  Source1         2  2016-02-08 11:51:46
# 3402773  A-3412656  Source1         2  2016-02-08 15:16:43
# 3402774  A-3412657  Source1         2  2016-02-08 15:43:50
#
#                     End_Time  Start_Lat  Start_Lng  Distance(mi)       Street  \
# 3402762  2016-02-08 06:37:08  40.108910 -83.092860         3.230  Outerbelt E
# 3402767  2016-02-08 13:53:43  39.172393 -84.492792         0.500       I-75 S
# 3402771  2016-02-08 17:51:46  41.375310 -81.820170         0.521       I-71 S
# 3402773  2016-02-08 21:16:43  40.109310 -82.968490         0.826  Outerbelt W
# 3402774  2016-02-08 21:43:50  39.192880 -84.477230         0.307       I-75 N
#
#                 City  ... Junction No_Exit Railway Roundabout  Station   Stop  \
# 3402762       Dublin  ...    False   False   False      False    False  False
# 3402767   Cincinnati  ...    False   False   False      False    False  False
# 3402771    Cleveland  ...     True   False   False      False    False  False
# 3402773  Westerville  ...    False   False   False      False    False  False
# 3402774   Cincinnati  ...    False   False   False      False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset
# 3402762            False           False         False          Night
# 3402767            False           False         False            Day
# 3402771            False           False         False            Day
# 3402773            False           False         False            Day
# 3402774            False           False         False            Day
#
# [5 rows x 36 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274636 entries, 3402762 to 4999999
# Data columns (total 36 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ID                 1274636 non-null  object
#  1   Source             1274636 non-null  object
#  2   Severity           1274636 non-null  int64
#  3   Start_Time         1274636 non-null  object
#  4   End_Time           1274636 non-null  object
#  5   Start_Lat          1274636 non-null  float64
#  6   Start_Lng          1274636 non-null  float64
#  7   Distance(mi)       1274636 non-null  float64
#  8   Street             1274636 non-null  object
#  9   City               1274636 non-null  object
#  10  County             1274636 non-null  object
#  11  State              1274636 non-null  object
#  12  Country            1274636 non-null  object
#  13  Weather_Timestamp  1274636 non-null  object
#  14  Temperature(F)     1274636 non-null  float64
#  15  Wind_Chill(F)      1274636 non-null  float64
#  16  Humidity(%)        1274636 non-null  float64
#  17  Pressure(in)       1274636 non-null  float64
#  18  Visibility(mi)     1274636 non-null  float64
#  19  Wind_Direction     1274636 non-null  object
#  20  Wind_Speed(mph)    1274636 non-null  float64
#  21  Precipitation(in)  1274636 non-null  float64
#  22  Weather_Condition  1274636 non-null  object
#  23  Bump               1274636 non-null  bool
#  24  Crossing           1274636 non-null  bool
#  25  Give_Way           1274636 non-null  bool
#  26  Junction           1274636 non-null  bool
#  27  No_Exit            1274636 non-null  bool
#  28  Railway            1274636 non-null  bool
#  29  Roundabout         1274636 non-null  bool
#  30  Station            1274636 non-null  bool
#  31  Stop               1274636 non-null  bool
#  32  Traffic_Calming    1274636 non-null  bool
#  33  Traffic_Signal     1274636 non-null  bool
#  34  Turning_Loop       1274636 non-null  bool
#  35  Sunrise_Sunset     1274636 non-null  object
# dtypes: bool(12), float64(10), int64(1), object(13)
# memory usage: 257.7+ MB

# %%
print(df_final.isnull().sum())
# Out:
# ID                   0
# Source               0
# Severity             0
# Start_Time           0
# End_Time             0
# Start_Lat            0
# Start_Lng            0
# Distance(mi)         0
# Street               0
# City                 0
# County               0
# State                0
# Country              0
# Weather_Timestamp    0
# Temperature(F)       0
# Wind_Chill(F)        0
# Humidity(%)          0
# Pressure(in)         0
# Visibility(mi)       0
# Wind_Direction       0
# Wind_Speed(mph)      0
# Precipitation(in)    0
# Weather_Condition    0
# Bump                 0
# Crossing             0
# Give_Way             0
# Junction             0
# No_Exit              0
# Railway              0
# Roundabout           0
# Station              0
# Stop                 0
# Traffic_Calming      0
# Traffic_Signal       0
# Turning_Loop         0
# Sunrise_Sunset       0
# dtype: int64

# %%
(df_final == 0).sum()
# Out:
# ID                         0
# Source                     0
# Severity                   0
# Start_Time                 0
# End_Time                   0
# Start_Lat                  0
# Start_Lng                  0
# Distance(mi)             533
# Street                     0
# City                       0
# County                     0
# State                      0
# Country                    0
# Weather_Timestamp          0
# Temperature(F)           816
# Wind_Chill(F)           1353
# Humidity(%)                0
# Pressure(in)               1
# Visibility(mi)          1937
# Wind_Direction             0
# Wind_Speed(mph)       201874
# Precipitation(in)    1175178
# Weather_Condition          0
# Bump                 1273864
# Crossing             1161954
# Give_Way             1270751
# Junction             1186383
# No_Exit              1271503
# Railway              1265342
# Roundabout           1274596
# Station              1240153
# Stop                 1241134
# Traffic_Calming      1273240
# Traffic_Signal       1177865
# Turning_Loop         1274636
# Sunrise_Sunset             0
# dtype: int64

# %%
df_final['Start_Time'] = pd.to_datetime(
    df_final['Start_Time'],
    format='mixed',
    errors='coerce'
)

df_final['Hour'] = df_final['Start_Time'].dt.hour

df_final['Day_of_Week'] = df_final['Start_Time'].dt.dayofweek

df_final['Is_Weekend'] = (
    df_final['Day_of_Week'] >= 5
).astype(int)

df_final['Is_Night'] = (
    (df_final['Hour'] >= 18) |
    (df_final['Hour'] <= 6)
).astype(int)
# Out:
# /tmp/ipykernel_34606/2984055376.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Start_Time'] = pd.to_datetime(
# /tmp/ipykernel_34606/2984055376.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Hour'] = df_final['Start_Time'].dt.hour
# /tmp/ipykernel_34606/2984055376.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Day_of_Week'] = df_final['Start_Time'].dt.dayofweek
# /tmp/ipykernel_34606/2984055376.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Is_Weekend'] = (
# /tmp/ipykernel_34606/2984055376.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Is_Night'] = (

# %%
df_final['Weather_Condition'] = (
    df_final['Weather_Condition']
    .astype(str)
    .str.lower()
)

df_final['Rain_Flag'] = df_final['Weather_Condition'].str.contains('rain').astype(int)
df_final['Fog_Flag'] = df_final['Weather_Condition'].str.contains('fog').astype(int)
df_final['Snow_Flag'] = df_final['Weather_Condition'].str.contains('snow').astype(int)
# Out:
# /tmp/ipykernel_34606/907676565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Weather_Condition'] = (
# /tmp/ipykernel_34606/907676565.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rain_Flag'] = df_final['Weather_Condition'].str.contains('rain').astype(int)
# /tmp/ipykernel_34606/907676565.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Fog_Flag'] = df_final['Weather_Condition'].str.contains('fog').astype(int)
# /tmp/ipykernel_34606/907676565.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Snow_Flag'] = df_final['Weather_Condition'].str.contains('snow').astype(int)

# %%
df_final['Risk_Level'] = (
    df_final['Severity'] >= 3
).astype(int)

print(df_final['Risk_Level'].value_counts())
# Out:
# Risk_Level
# 0    1238268
# 1      36368
# Name: count, dtype: int64
# /tmp/ipykernel_34606/3762400758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Risk_Level'] = (

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274636 entries, 3402762 to 4999999
# Data columns (total 44 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ID                 1274636 non-null  object
#  1   Source             1274636 non-null  object
#  2   Severity           1274636 non-null  int64
#  3   Start_Time         1274636 non-null  datetime64[ns]
#  4   End_Time           1274636 non-null  object
#  5   Start_Lat          1274636 non-null  float64
#  6   Start_Lng          1274636 non-null  float64
#  7   Distance(mi)       1274636 non-null  float64
#  8   Street             1274636 non-null  object
#  9   City               1274636 non-null  object
#  10  County             1274636 non-null  object
#  11  State              1274636 non-null  object
#  12  Country            1274636 non-null  object
#  13  Weather_Timestamp  1274636 non-null  object
#  14  Temperature(F)     1274636 non-null  float64
#  15  Wind_Chill(F)      1274636 non-null  float64
#  16  Humidity(%)        1274636 non-null  float64
#  17  Pressure(in)       1274636 non-null  float64
#  18  Visibility(mi)     1274636 non-null  float64
#  19  Wind_Direction     1274636 non-null  object
#  20  Wind_Speed(mph)    1274636 non-null  float64
#  21  Precipitation(in)  1274636 non-null  float64
#  22  Weather_Condition  1274636 non-null  object
#  23  Bump               1274636 non-null  bool
#  24  Crossing           1274636 non-null  bool
#  25  Give_Way           1274636 non-null  bool
#  26  Junction           1274636 non-null  bool
#  27  No_Exit            1274636 non-null  bool
#  28  Railway            1274636 non-null  bool
#  29  Roundabout         1274636 non-null  bool
#  30  Station            1274636 non-null  bool
#  31  Stop               1274636 non-null  bool
#  32  Traffic_Calming    1274636 non-null  bool
#  33  Traffic_Signal     1274636 non-null  bool
#  34  Turning_Loop       1274636 non-null  bool
#  35  Sunrise_Sunset     1274636 non-null  object
#  36  Hour               1274636 non-null  int32
#  37  Day_of_Week        1274636 non-null  int32
#  38  Is_Weekend         1274636 non-null  int64
#  39  Is_Night           1274636 non-null  int64
#  40  Rain_Flag          1274636 non-null  int64
#  41  Fog_Flag           1274636 non-null  int64
#  42  Snow_Flag          1274636 non-null  int64
#  43  Risk_Level         1274636 non-null  int64
# dtypes: bool(12), datetime64[ns](1), float64(10), int32(2), int64(7), object(12)
# memory usage: 325.8+ MB

# %%
final_features = [
    'Hour',
    'Day_of_Week',
    'Is_Weekend',
    'Is_Night',
    'Rain_Flag',
    'Fog_Flag',
    'Snow_Flag',
    'Start_Lat',
    'Start_Lng',
    'Distance(mi)',
    'Street',
    'City',
    'County',
    'State',
    'Country',
    'Weather_Timestamp',
    'Temperature(F)',
    'Wind_Chill(F)',
    'Humidity(%)',
    'Pressure(in)',
    'Visibility(mi)',
    'Wind_Direction',
    'Wind_Speed(mph)',
    'Precipitation(in)',
    'Bump',
    'Crossing',
    'Give_Way',
    'Junction',
    'No_Exit',
    'Railway',
    'Roundabout',
    'Station',
    'Stop',
    'Traffic_Calming',
    'Traffic_Signal',
    'Turning_Loop',
    'Sunrise_Sunset'
]

# %%
X = df_final[final_features]
y = df_final['Risk_Level']

# %%
output1_file = "after_preprocessing.csv"

# %%
df_final.to_csv(output1_file, index= False)

# %%
print(X.isnull().sum())
# Out:
# Hour                 0
# Day_of_Week          0
# Is_Weekend           0
# Is_Night             0
# Rain_Flag            0
# Fog_Flag             0
# Snow_Flag            0
# Start_Lat            0
# Start_Lng            0
# Distance(mi)         0
# Street               0
# City                 0
# County               0
# State                0
# Country              0
# Weather_Timestamp    0
# Temperature(F)       0
# Wind_Chill(F)        0
# Humidity(%)          0
# Pressure(in)         0
# Visibility(mi)       0
# Wind_Direction       0
# Wind_Speed(mph)      0
# Precipitation(in)    0
# Bump                 0
# Crossing             0
# Give_Way             0
# Junction             0
# No_Exit              0
# Railway              0
# Roundabout           0
# Station              0
# Stop                 0
# Traffic_Calming      0
# Traffic_Signal       0
# Turning_Loop         0
# Sunrise_Sunset       0
# dtype: int64

# %%
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
print(X.dtypes)
# Out:
# Hour                   int32
# Day_of_Week            int32
# Is_Weekend             int64
# Is_Night               int64
# Rain_Flag              int64
# Fog_Flag               int64
# Snow_Flag              int64
# Start_Lat            float64
# Start_Lng            float64
# Distance(mi)         float64
# Street                object
# City                  object
# County                object
# State                 object
# Country               object
# Weather_Timestamp     object
# Temperature(F)       float64
# Wind_Chill(F)        float64
# Humidity(%)          float64
# Pressure(in)         float64
# Visibility(mi)       float64
# Wind_Direction        object
# Wind_Speed(mph)      float64
# Precipitation(in)    float64
# Bump                    bool
# Crossing                bool
# Give_Way                bool
# Junction                bool
# No_Exit                 bool
# Railway                 bool
# Roundabout              bool
# Station                 bool
# Stop                    bool
# Traffic_Calming         bool
# Traffic_Signal          bool
# Turning_Loop            bool
# Sunrise_Sunset        object
# dtype: object

# %%
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_34606/3292101295.py in <cell line: 0>()
#       4 )
#       5
# ----> 6 model.fit(X, y)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     358             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     359
# --> 360         X, y = validate_data(
#     361             self,
#     362             X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959             y = check_array(y, input_name="y", **check_y_params)
#    2960         else:
# -> 2961             X, y = check_X_y(X, y, **check_params)
#    2962         out = X, y
#    2963
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368     ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1369
# -> 1370     X = check_array(
#    1371         X,
#    1372         accept_sparse=accept_sparse,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     971         # Use the original dtype for conversion if dtype is None
#     972         new_dtype = dtype_orig if dtype is None else dtype
# --> 973         array = array.astype(new_dtype)
#     974         # Since we converted here, we do not need to convert again later
#     975         dtype = None
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     180
#     181     else:
# --> 182         values = _astype_nansafe(values, dtype, copy=copy)
#     183
#     184     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in _astype_nansafe(arr, dtype, copy, skipna)
#     131     if copy or arr.dtype == object or dtype == object:
#     132         # Explicit copy, or required since NumPy can't view from / to object.
# --> 133         return arr.astype(dtype, copy=True)
#     134
#     135     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Outerbelt E'

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importaance': model.feature_importnaces_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print(importance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_34606/2945019676.py in <cell line: 0>()
#       1 importance = pd.DataFrame({
#       2     'Feature': X.columns,
# ----> 3     'Importaance': model.feature_importnaces_
#       4 })
#       5
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'feature_importnaces_'

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x='Importance',
    y='Feature',
    data=importance
)

plt.title(
    'RoadVision AI Feature Importance'
)

plt.show()
